# %% [markdown]
# #### This is my first Notebook for Project 5: AI Radiologists

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pathlib
import imageio
import PIL
from PIL import Image
import os
from pandas import DataFrame

# %%
cd AIRadiologists/
# Out:
# /Users/melissamcmillan/Documents/Python_Stuff/GA_DSI_Course/Project_5/AIRadiologists

# %%
covid_images = '/Users/melissamcmillan/Documents/Python_Stuff/GA_DSI_Course/COVID-19_Radiography_Database/COVID/'

# %%
image_1 = Image.open('/Users/melissamcmillan/Documents/Python_Stuff/GA_DSI_Course/COVID-19_Radiography_Database/COVID/COVID (1).png')

# %%
print(image_1.format)
print(image_1.size)
print(image_1.mode)
# show the image
image_1.show()
# Out:
# PNG
# (256, 256)
# L

# %%
covid_files = []
for filename in os.listdir(covid_images):
    if filename.endswith(".png"): 
         # print(os.path.join(directory, filename))
        covid_files.append(filename)

# %%
len(covid_files)
# Out:
# 1200

# %%
covid_files[0:3]
# Out:
# ['COVID (640).png', 'COVID (210).png', 'COVID (705).png']

# %%
#make covid_images your variable to the directory where you have stored the COVID x-ray images
normal_images = '/Users/melissamcmillan/Documents/Python_Stuff/GA_DSI_Course/COVID-19_Radiography_Database/NORMAL/'

#this will allow you to open an image and confirm you can access the images in the directory; just a check really
image_2 = Image.open('/Users/melissamcmillan/Documents/Python_Stuff/GA_DSI_Course/COVID-19_Radiography_Database/NORMAL/NORMAL (1).png')
print(image_2.format)
print(image_2.size)
print(image_2.mode)
# show the image
image_2.show()

#this will loop through the images in the covid directory and add each image to the master list
normal_files = []
for filename in os.listdir(normal_images):
    if filename.endswith(".png"): 
         # print(os.path.join(directory, filename))
        normal_files.append(filename)

#check the length of the master list to make sure it's what we expect; should return 1200 in this case
len(normal_files)
# Out:
# PNG
# (1024, 1024)
# L
# 1341

# %%
normal_files[:3]
# Out:
# ['NORMAL (1295).png', 'NORMAL (958).png', 'NORMAL (688).png']

# %%
#make covid_images your variable to the directory where you have stored the COVID x-ray images
pneum_images = '/Users/melissamcmillan/Documents/Python_Stuff/GA_DSI_Course/COVID-19_Radiography_Database/Viral Pneumonia/'

#this will allow you to open an image and confirm you can access the images in the directory; just a check really
image_3 = Image.open('/Users/melissamcmillan/Documents/Python_Stuff/GA_DSI_Course/COVID-19_Radiography_Database/Viral Pneumonia/Viral Pneumonia (1).png')
print(image_3.format)
print(image_3.size)
print(image_3.mode)
# show the image
image_3.show()

#this will loop through the images in the covid directory and add each image to the master list
pneum_files = []
for filename in os.listdir(pneum_images):
    if filename.endswith(".png"): 
         # print(os.path.join(directory, filename))
        pneum_files.append(filename)

#check the length of the master list to make sure it's what we expect; should return 1200 in this case
len(pneum_files)
# Out:
# PNG
# (1024, 1024)
# L
# 1345

# %%
master_list = []

# %%
for element in covid_files:
    master_list.append(Image.open('/Users/melissamcmillan/Documents/Python_Stuff/GA_DSI_Course/COVID-19_Radiography_Database/COVID/' + element))
master_list[0:3]
# Out:
# [<PIL.PngImagePlugin.PngImageFile image mode=L size=331x331 at 0x7F8781D45D60>,
#  <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7F8781DF74C0>,
#  <PIL.PngImagePlugin.PngImageFile image mode=L size=331x331 at 0x7F8781DF7C70>]

# %%
type(master_list)
# Out:
# list

# %%
plt.imshow(master_list[0], cmap='gray')

# %%
for element in normal_files:
    master_list.append(Image.open('/Users/melissamcmillan/Documents/Python_Stuff/GA_DSI_Course/COVID-19_Radiography_Database/NORMAL/' + element))
len(master_list)
# Out:
# 2541

# %%
plt.imshow(master_list[-1], cmap='gray')

# %%
for element in pneum_files:
    master_list.append(Image.open('/Users/melissamcmillan/Documents/Python_Stuff/GA_DSI_Course/COVID-19_Radiography_Database/Viral Pneumonia/' + element))
len(master_list)
# Out:
# 3886

# %%
plt.imshow(master_list[-1], cmap='gray')

# %%
images_df = DataFrame(master_list, columns = ['images'])
images_df['type'] = 'covid'

# %%
images_df['images'].iloc[1200]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1024x1024 at 0x7F8781DF7580>

# %%
images_df['images'].iloc[2541]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1024x1024 at 0x7F8781D6BD90>

# %%
images_df['type'].iloc[1200:2541] = 'normal'
images_df['type'].iloc[2541:] = 'pneumonia'

# %%
images_df.iloc[1199:1203]
# Out:
#                                                  images    type
# 1199  <PIL.PngImagePlugin.PngImageFile image mode=L ...   covid
# 1200  <PIL.PngImagePlugin.PngImageFile image mode=L ...  normal
# 1201  <PIL.PngImagePlugin.PngImageFile image mode=L ...  normal
# 1202  <PIL.PngImagePlugin.PngImageFile image mode=L ...  normal

# %%
images_df.iloc[2539:2543]
# Out:
#                                                  images       type
# 2539  <PIL.PngImagePlugin.PngImageFile image mode=L ...     normal
# 2540  <PIL.PngImagePlugin.PngImageFile image mode=L ...     normal
# 2541  <PIL.PngImagePlugin.PngImageFile image mode=L ...  pneumonia
# 2542  <PIL.PngImagePlugin.PngImageFile image mode=L ...  pneumonia

# %%
images_df
# Out:
#                                                  images       type
# 0     <PIL.PngImagePlugin.PngImageFile image mode=L ...      covid
# 1     <PIL.PngImagePlugin.PngImageFile image mode=L ...      covid
# 2     <PIL.PngImagePlugin.PngImageFile image mode=L ...      covid
# 3     <PIL.PngImagePlugin.PngImageFile image mode=L ...      covid
# 4     <PIL.PngImagePlugin.PngImageFile image mode=L ...      covid
# ...                                                 ...        ...
# 3881  <PIL.PngImagePlugin.PngImageFile image mode=L ...  pneumonia
# 3882  <PIL.PngImagePlugin.PngImageFile image mode=L ...  pneumonia
# 3883  <PIL.PngImagePlugin.PngImageFile image mode=L ...  pneumonia
# 3884  <PIL.PngImagePlugin.PngImageFile image mode=L ...  pneumonia
# 3885  <PIL.PngImagePlugin.PngImageFile image mode=L ...  pneumonia
#
# [3886 rows x 2 columns]

# %%
pwd
# Out:
# '/Users/melissamcmillan/Documents/Python_Stuff/GA_DSI_Course/Project_5/AIRadiologists'

# %%
images_df.to_csv('./all_images_labeled_2.csv')

# %%
plt.imshow(images_df['images'].iloc[-1], cmap = 'gray')
